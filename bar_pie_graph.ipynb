# %% [markdown]
# # My first project all by myself

# %% [markdown]
# # 1. importing the neccessary softwares

# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')
df.head(5)
# Out:
#      Name  Age  Test Score Grade
# 0   James   21          78     B
# 1  Olivia   19          88     A
# 2    Liam   23          67     C
# 3    Emma   20          92     A
# 4    Noah   22          73     B

# %%
df.tail(3)
# Out:
#    Name  Age  Test Score Grade
# 2  Liam   23          67     C
# 3  Emma   20          92     A
# 4  Noah   22          73     B

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# Test Score     int64
# Grade         object
# dtype: object

# %%
df.count()
# Out:
# Name          5
# Age           5
# Test Score    5
# Grade         5
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Name          0
# Age           0
# Test Score    0
# Grade         0
# dtype: int64

# %%
df['Test Score'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Age'].value_counts().plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Age'].value_counts().plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Age'].value_counts().plot.pie(autopct='1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.plot.bar(x ='Age', y ='Test Score')
# Out:
# <Axes: xlabel='Age'>

# %%
import matplotlib.pyplot as plt

df.plot.bar(x='Name', y='Test Score')
plt.xlabel('Students')
plt.ylabel('Scores')
plt.title('Test Scores by Student')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(df['Name'], df['Test Score'], color='lightskyblue')
plt.xlabel('Students')
plt.ylabel('Test Score')
plt.title('Test Scores by Student')
plt.show()

# %%
df.plot.bar(x ='Test Score', y ='Age')
# Out:
# <Axes: xlabel='Test Score'>

# %%
import matplotlib.pyplot as plt
plt.bar(df['Age'], df['Test Score'], color ='lightskyblue')
plt.xlabel('Years Old')
plt.ylabel('Test Score')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
fig, ax= plt.subplots(figsize=(10,6))
ax.scatter(df['Test Score'], df['Age'])
ax.set_xlabel('Test Score')
ax.set_ylabel('Age')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df['Test Score'], df['Age'])
ax.set_xlabel('Test Score')
ax.set_ylabel('Age')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df['Age'], df['Test Score'])
ax.set_xlabel('Age')
ax.set_ylabel('Test Score')
plt.show()

# %%
plt.bar(df['Test Score'], df['Age'], color = 'lightskyblue')
plt.xlabel('Test Score')
plt.ylabel('Age')
plt.title('Test Scores by Age')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df['Age'], df['Test Score'])
ax.set_xlabel('Age')
ax.set_ylabel('Test Score')
ax.set_title('Test Score by Age')
plt.show()

# %%
df['Age'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df['Age'], df['Test Score'])
ax.set_xlabel('Age')
ax.set_ylabel('Test Score')
ax.set_title('Test Scores by Age')
plt.show()

# %%
df['Test Score'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
plt.bar(df['Age'], df['Test Score'], color = 'lightskyblue')
plt.xlabel('Age')
plt.ylabel('Test Score')
plt.title('Test Score by Age')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df['Age'], df['Test Score'])
ax.set_xlabel('Age')
ax.set_ylabel('Test Score')
ax.set_title('Test Score by Age')
plt.show()

# %%
df['Age'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(df['Age'], df['Test Score'])
ax.set_xlabel('Age')
ax.set_ylabel('Test Score')
ax.set_title('Test Score by Age')
plt.show()
